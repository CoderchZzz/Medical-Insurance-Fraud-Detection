# %% [markdown]
# # 数据处理
#
# > 2024/02/19 by Leeasy

# %% [markdown]
# ## 1. 数据预处理

# %% [markdown]
# ### 数据清洗：处理缺失值、异常值和重复记录。

# %%
import pandas as pd

# 加载数据集
df = pd.read_csv('data-0.csv')

# 显示数据集的基本信息，包括每列的类型和非空值的数量
print(df.info())

# 查找列中包含的缺失值数
print(df.isnull().sum())

# 处理缺失值：你可以选择填充缺失值或者删除包含缺失值的行
# 例如，使用均值填充数值型特征的缺失值
for col in df.select_dtypes(include=['float', 'int']).columns:
    df[col].fillna(df[col].mean(), inplace=True)

# 对于分类特征，可以使用众数来填充缺失值
for col in df.select_dtypes(include=['object']).columns:
    df[col].fillna(df[col].mode()[0], inplace=True)

# 删除重复记录
df.drop_duplicates(inplace=True)

# 处理异常值：这需要根据具体情况来定义什么是异常值。
# 作为示例，这里我们简单地使用了标准差来识别异常值。
for col in df.select_dtypes(include=['float', 'int']).columns:
    deviation = df[col].std()
    mean_val = df[col].mean()
    # 假设异常值定义为均值加减3倍标准差之外的值
    outliers = (df[col] > mean_val + 3 * deviation) | (df[col] < mean_val - 3 * deviation)
    df = df[~outliers]

print("数据清洗后的数据集信息：")
print(df.info())

# 保存清洗后的数据集
df.to_csv('data-0_clean.csv', index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16000 entries, 0 to 15999
# Data columns (total 82 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   个人编码               16000 non-null  float64
#  1   一天去两家医院的天数         16000 non-null  int64
#  2   就诊的月数              16000 non-null  int64
#  3   月就诊天数_MAX          16000 non-null  int64
#  4   月就诊天数_AVG          16000 non-null  float64
#  5   月就诊医院数_MAX         16000 non-null  int64
#  6   月就诊医院数_AVG         16000 non-null  float64
#  7   就诊次数_SUM           16000 non-null  int64
#  8   月就诊次数_MAX          16000 non-null  int64
#  9   月就诊次数_AVG          16000 non-null  float64
#  10  月统筹金额_MAX          16000 non-null  float64
#  11  月统筹金额_AVG          16000 non-null  float64
#  12  月药品金额_MAX          16000 non-null  float64
#  13  月药品金额_AVG          16000 non-null  float64
#  14  医院_就诊天数_MAX        16000 non-null  int64
#  15  医院_就诊天数_AVG        16000 non-null  float64
#  16  医院_统筹金_MAX         16000 non-null  float64
#  17  医院_统筹金_AVG         16000 non-null  float64
#  18  医院_药品_MAX          16000 non-null  float64
#  19  医院_药品_AVG          16000 non-null  float64
#  20  医院编码_NN            16000 non-null  int64
#  21  顺序号_NN             16000 non-null  int64
#  22  交易时间DD_NN          16000 non-null  int64
#  23  交易时间YYYY_NN        16000 non-null  int64
#  24  交易时间YYYYMM_NN      16000 non-null  int64
#  25  住院天数_SUM           16000 non-null  int64
#  26  个人账户金额_SUM         16000 non-null  float64
#  27  统筹支付金额_SUM         16000 non-null  float64
#  28  ALL_SUM            16000 non-null  float64
#  29  可用账户报销金额_SUM       16000 non-null  float64
#  30  药品费发生金额_SUM        16000 non-null  float64
#  31  药品费自费金额_SUM        16000 non-null  float64
#  32  药品费申报金额_SUM        16000 non-null  float64
#  33  贵重药品发生金额_SUM       16000 non-null  float64
#  34  中成药费发生金额_SUM       16000 non-null  float64
#  35  中草药费发生金额_SUM       16000 non-null  float64
#  36  检查费发生金额_SUM        16000 non-null  float64
#  37  检查费自费金额_SUM        16000 non-null  float64
#  38  检查费申报金额_SUM        16000 non-null  float64
#  39  贵重检查费金额_SUM        16000 non-null  int64
#  40  治疗费发生金额_SUM        16000 non-null  float64
#  41  治疗费自费金额_SUM        16000 non-null  float64
#  42  治疗费申报金额_SUM        16000 non-null  float64
#  43  手术费发生金额_SUM        16000 non-null  int64
#  44  手术费自费金额_SUM        16000 non-null  int64
#  45  手术费申报金额_SUM        16000 non-null  float64
#  46  床位费发生金额_SUM        16000 non-null  float64
#  47  床位费申报金额_SUM        16000 non-null  float64
#  48  医用材料发生金额_SUM       16000 non-null  float64
#  49  高价材料发生金额_SUM       16000 non-null  float64
#  50  医用材料费自费金额_SUM      16000 non-null  float64
#  51  成分输血申报金额_SUM       16000 non-null  int64
#  52  其它发生金额_SUM         16000 non-null  float64
#  53  其它申报金额_SUM         16000 non-null  int64
#  54  一次性医用材料申报金额_SUM    16000 non-null  float64
#  55  起付线标准金额_MAX        16000 non-null  float64
#  56  起付标准以上自负比例金额_SUM   16000 non-null  float64
#  57  医疗救助个人按比例负担金额_SUM  16000 non-null  float64
#  58  最高限额以上金额_SUM       16000 non-null  float64
#  59  基本统筹基金支付金额_SUM     16000 non-null  float64
#  60  公务员医疗补助基金支付金额_SUM  16000 non-null  float64
#  61  城乡救助补助金额_SUM       16000 non-null  float64
#  62  基本个人账户支付_SUM       16000 non-null  float64
#  63  非账户支付金额_SUM        16000 non-null  float64
#  64  本次审批金额_SUM         16000 non-null  float64
#  65  补助审批金额_SUM         16000 non-null  float64
#  66  医疗救助医院申请_SUM       16000 non-null  float64
#  67  残疾军人补助_SUM         16000 non-null  float64
#  68  民政救助补助_SUM         16000 non-null  float64
#  69  城乡优抚补助_SUM         16000 non-null  float64
#  70  出院诊断病种名称_NN        16000 non-null  int64
#  71  出院诊断LENTH_MAX      15645 non-null  float64
#  72  药品在总金额中的占比         16000 non-null  float64
#  73  个人支付的药品占比          16000 non-null  float64
#  74  检查总费用在总金额占比        16000 non-null  float64
#  75  个人支付检查费用占比         16000 non-null  float64
#  76  治疗费用在总金额占比         16000 non-null  float64
#  77  个人支付治疗费用占比         16000 non-null  float64
#  78  BZ_民政救助            16000 non-null  int64
#  79  BZ_城乡优抚            16000 non-null  int64
#  80  是否挂号               16000 non-null  int64
#  81  RES                16000 non-null  int64
# dtypes: float64(59), int64(23)
# memory usage: 10.0 MB
# None
# 个人编码          0
# 一天去两家医院的天数    0
# 就诊的月数         0
# 月就诊天数_MAX     0
# 月就诊天数_AVG     0
#              ..
# 个人支付治疗费用占比    0
# BZ_民政救助       0
# BZ_城乡优抚       0
# 是否挂号          0
# RES           0
# Length: 82, dtype: int64
# 数据清洗后的数据集信息：
# <class 'pandas.core.frame.DataFrame'>
# Index: 6185 entries, 0 to 15837
# Data columns (total 82 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   个人编码               6185 non-null   float64
#  1   一天去两家医院的天数         6185 non-null   int64
#  2   就诊的月数              6185 non-null   int64
#  3   月就诊天数_MAX          6185 non-null   int64
#  4   月就诊天数_AVG          6185 non-null   float64
#  5   月就诊医院数_MAX         6185 non-null   int64
#  6   月就诊医院数_AVG         6185 non-null   float64
#  7   就诊次数_SUM           6185 non-null   int64
#  8   月就诊次数_MAX          6185 non-null   int64
#  9   月就诊次数_AVG          6185 non-null   float64
#  10  月统筹金额_MAX          6185 non-null   float64
#  11  月统筹金额_AVG          6185 non-null   float64
#  12  月药品金额_MAX          6185 non-null   float64
#  13  月药品金额_AVG          6185 non-null   float64
#  14  医院_就诊天数_MAX        6185 non-null   int64
#  15  医院_就诊天数_AVG        6185 non-null   float64
#  16  医院_统筹金_MAX         6185 non-null   float64
#  17  医院_统筹金_AVG         6185 non-null   float64
#  18  医院_药品_MAX          6185 non-null   float64
#  19  医院_药品_AVG          6185 non-null   float64
#  20  医院编码_NN            6185 non-null   int64
#  21  顺序号_NN             6185 non-null   int64
#  22  交易时间DD_NN          6185 non-null   int64
#  23  交易时间YYYY_NN        6185 non-null   int64
#  24  交易时间YYYYMM_NN      6185 non-null   int64
#  25  住院天数_SUM           6185 non-null   int64
#  26  个人账户金额_SUM         6185 non-null   float64
#  27  统筹支付金额_SUM         6185 non-null   float64
#  28  ALL_SUM            6185 non-null   float64
#  29  可用账户报销金额_SUM       6185 non-null   float64
#  30  药品费发生金额_SUM        6185 non-null   float64
#  31  药品费自费金额_SUM        6185 non-null   float64
#  32  药品费申报金额_SUM        6185 non-null   float64
#  33  贵重药品发生金额_SUM       6185 non-null   float64
#  34  中成药费发生金额_SUM       6185 non-null   float64
#  35  中草药费发生金额_SUM       6185 non-null   float64
#  36  检查费发生金额_SUM        6185 non-null   float64
#  37  检查费自费金额_SUM        6185 non-null   float64
#  38  检查费申报金额_SUM        6185 non-null   float64
#  39  贵重检查费金额_SUM        6185 non-null   int64
#  40  治疗费发生金额_SUM        6185 non-null   float64
#  41  治疗费自费金额_SUM        6185 non-null   float64
#  42  治疗费申报金额_SUM        6185 non-null   float64
#  43  手术费发生金额_SUM        6185 non-null   int64
#  44  手术费自费金额_SUM        6185 non-null   int64
#  45  手术费申报金额_SUM        6185 non-null   float64
#  46  床位费发生金额_SUM        6185 non-null   float64
#  47  床位费申报金额_SUM        6185 non-null   float64
#  48  医用材料发生金额_SUM       6185 non-null   float64
#  49  高价材料发生金额_SUM       6185 non-null   float64
#  50  医用材料费自费金额_SUM      6185 non-null   float64
#  51  成分输血申报金额_SUM       6185 non-null   int64
#  52  其它发生金额_SUM         6185 non-null   float64
#  53  其它申报金额_SUM         6185 non-null   int64
#  54  一次性医用材料申报金额_SUM    6185 non-null   float64
#  55  起付线标准金额_MAX        6185 non-null   float64
#  56  起付标准以上自负比例金额_SUM   6185 non-null   float64
#  57  医疗救助个人按比例负担金额_SUM  6185 non-null   float64
#  58  最高限额以上金额_SUM       6185 non-null   float64
#  59  基本统筹基金支付金额_SUM     6185 non-null   float64
#  60  公务员医疗补助基金支付金额_SUM  6185 non-null   float64
#  61  城乡救助补助金额_SUM       6185 non-null   float64
#  62  基本个人账户支付_SUM       6185 non-null   float64
#  63  非账户支付金额_SUM        6185 non-null   float64
#  64  本次审批金额_SUM         6185 non-null   float64
#  65  补助审批金额_SUM         6185 non-null   float64
#  66  医疗救助医院申请_SUM       6185 non-null   float64
#  67  残疾军人补助_SUM         6185 non-null   float64
#  68  民政救助补助_SUM         6185 non-null   float64
#  69  城乡优抚补助_SUM         6185 non-null   float64
#  70  出院诊断病种名称_NN        6185 non-null   int64
#  71  出院诊断LENTH_MAX      6185 non-null   float64
#  72  药品在总金额中的占比         6185 non-null   float64
#  73  个人支付的药品占比          6185 non-null   float64
#  74  检查总费用在总金额占比        6185 non-null   float64
#  75  个人支付检查费用占比         6185 non-null   float64
#  76  治疗费用在总金额占比         6185 non-null   float64
#  77  个人支付治疗费用占比         6185 non-null   float64
#  78  BZ_民政救助            6185 non-null   int64
#  79  BZ_城乡优抚            6185 non-null   int64
#  80  是否挂号               6185 non-null   int64
#  81  RES                6185 non-null   int64
# dtypes: float64(59), int64(23)
# memory usage: 3.9 MB
# None

# %% [markdown]
# 数据转换：对非数值型数据进行编码，如 One-Hot 编码。
# 特征规范化：将特征缩放到统一的范围或分布。
